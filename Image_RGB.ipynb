# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2

# %%
gray_image_cv=cv2.imread('T:\Advance AI\images\Grayscale_8bits_palette_sample_image.png',0)
print(gray_image_cv)
# Out:
# [[  0   0   0 ...   3   0   0]
#  [  0   0   0 ...  33  13   0]
#  [  4   1   0 ...  96  65   6]
#  ...
#  [124 133 139 ...  33  13   8]
#  [128 138 145 ...  35  28  28]
#  [135 137 136 ...  35  28  34]]

# %%
cv2.imshow('balck-white',gray_image_cv)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
# can balck-white(gray) turn to color lets see it
gray_image_cv=cv2.imread('T:\Advance AI\images\Grayscale_8bits_palette_sample_image.png',1)

# %%
cv2.imshow('balck-white',gray_image_cv)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
# It didnt work so gray image can't convert to colour image

# %% [markdown]
# # RGB How it works

# %%
Matplotlib works with RGB
open CV2 works with BGR

# %%
original_color_image_cv=cv2.imread('T:\Advance AI\images\lena_color_512.tif',1)# Cv2-BGR
plt.imshow(original_color_image_cv)# RGB

# %%
# to overcome this we use

# %%
original_color_image_cv=cv2.imread('T:\Advance AI\images\lena_color_512.tif',1)# Cv2-BGR
plt.imshow(original_color_image_cv[:,:,::-1])# RGB

# %%
original_color_image_cv=cv2.imread('T:\Advance AI\images\lena_color_512.tif',1)

# %%
b_channel=original_color_image_cv[:,:,0]# blue image
g_channel=original_color_image_cv[:,:,1]# green image
r_channel=original_color_image_cv[:,:,2]# red image

# %%
plt.subplot(2,2,1)
plt.imshow(original_color_image_cv[:,:,::-1],cmap='gray')
plt.subplot(2,2,2)
plt.imshow(b_channel,cmap='gray')
plt.subplot(2,2,3)
plt.imshow(g_channel,cmap='gray')
plt.subplot(2,2,4)
plt.imshow(r_channel,cmap='gray')
plt.show()
